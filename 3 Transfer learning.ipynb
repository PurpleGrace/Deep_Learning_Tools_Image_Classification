# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np
import pandas as pd
import os
from dotenv import load_dotenv
import time
from collections import Counter
import random
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score, precision_score,recall_score,confusion_matrix,classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import InputLayer,Conv2D,MaxPooling2D,MaxPool2D,Flatten,Dense,Dropout
from tensorflow.keras.preprocessing import image as IMG

# %%
with open('image_data_array.pickle','rb') as file:
    data = pickle.load(file)

# %%
X_train, X_test,X_val,y_train,y_test,y_val = data[0],data[1],data[2],data[3],data[4],data[5]

#Split data into train and validation set
#X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,random_state = 17,shuffle =True,test_size =.2)

y_train_hotcode = keras.utils.to_categorical(y_train)
y_val_hotcode = keras.utils.to_categorical(y_val)
y_test_hotcode = keras.utils.to_categorical(y_test)

# %%
IMGgen = IMG.ImageDataGenerator(
        #featurewise_center=True,
        #featurewise_std_normalization=True,
        #rescale=1./255,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)


train_ds = IMGgen.flow(X_train, y_train, batch_size=32)
val_ds = IMGgen.flow(X_val, y_val, batch_size=16)

# %% [markdown]
# # Transfer Learning with Xception

# %% [markdown]
# ## Freeze Xception parameter and exclude top layers

# %%
Xception_base = keras.applications.Xception(weights="imagenet", 
                                            input_shape=(150, 150, 3),
                                            include_top=False) 

Xception_base.trainable = False

# %%
if os.path.exists("model_h5_file/Xception_model_array.h5") == False:
    

    inputs = keras.Input(shape=(150, 150, 3))

    #x = data_augmentation(inputs)  # Apply random data augmentation
    
    x = keras.applications.xception.preprocess_input(inputs)
    x = Xception_base(x, training=False)
    
    x = Flatten()(x)
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)
    outputs = keras.layers.Dense(8)(x)
    Xception = keras.Model(inputs, outputs)

    Xception.summary()



    Xception.compile(
        #loss='categorical_crossentropy',
        loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        #optimizer= keras.optimizers.Adam(learning_rate=0.01),
        optimizer = 'Adam',
        metrics=['accuracy'],
    )



    Xception_result = Xception.fit(train_ds,
                                validation_data= val_ds,
                                epochs=30, verbose=1, 
                                callbacks = keras.callbacks.EarlyStopping(patience=5))  # track progress as we fit

    time2 = time.time()
    Xception.save("model_h5_file/Xception_model_array.h5")
    with open('Xception_result.pickle','wb')as file:
        pickle.dump(Xception_result, file)

else: 
    Xception = keras.models.load_model('model_h5_file/Xception_model_array.h5')
        
    with open('Xception_result.pickle','rb') as file:
        Xception_result = pickle.load(file)
# Out:
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_43 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  tf.math.truediv_6 (TFOpLamb  (None, 150, 150, 3)      0
#  da)
#
#  tf.math.subtract_6 (TFOpLam  (None, 150, 150, 3)      0
#  bda)
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense_51 (Dense)            (None, 32)                1638432
#
#  dropout_30 (Dropout)        (None, 32)                0
#
#  dense_52 (Dense)            (None, 32)                1056
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_53 (Dense)            (None, 32)                1056
#
#  dropout_32 (Dropout)        (None, 32)                0
#
#  dense_54 (Dense)            (None, 8)                 264
#
# =================================================================
# Total params: 22,502,288
# Trainable params: 1,640,808
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/30
# 130/130 [==============================] - 452s 3s/step - loss: 7.4778 - accuracy: 0.5329 - val_loss: 3.4721 - val_accuracy: 0.6679
# Epoch 2/30
# 130/130 [==============================] - 383s 3s/step - loss: 4.8369 - accuracy: 0.6015 - val_loss: 1.9289 - val_accuracy: 0.7404
# Epoch 3/30
# 130/130 [==============================] - 353s 3s/step - loss: 3.4587 - accuracy: 0.6166 - val_loss: 1.5837 - val_accuracy: 0.7498
# Epoch 4/30
# 130/130 [==============================] - 404s 3s/step - loss: 2.6300 - accuracy: 0.6489 - val_loss: 1.3343 - val_accuracy: 0.7585
# Epoch 5/30
# 130/130 [==============================] - 408s 3s/step - loss: 2.1574 - accuracy: 0.6563 - val_loss: 1.2565 - val_accuracy: 0.7360
# Epoch 6/30
# 130/130 [==============================] - 464s 4s/step - loss: 1.7361 - accuracy: 0.6772 - val_loss: 0.9944 - val_accuracy: 0.7825
# Epoch 7/30
# 130/130 [==============================] - 469s 4s/step - loss: 1.4366 - accuracy: 0.6914 - val_loss: 1.0060 - val_accuracy: 0.7440
# Epoch 8/30
# 130/130 [==============================] - 459s 4s/step - loss: 1.2019 - accuracy: 0.7066 - val_loss: 0.9192 - val_accuracy: 0.7542
# Epoch 9/30
# 130/130 [==============================] - 502s 4s/step - loss: 1.0576 - accuracy: 0.7145 - val_loss: 0.8634 - val_accuracy: 0.7498
# Epoch 10/30
# 130/130 [==============================] - 503s 4s/step - loss: 0.9480 - accuracy: 0.7321 - val_loss: 0.7833 - val_accuracy: 0.7665
# Epoch 11/30
# 130/130 [==============================] - 459s 4s/step - loss: 0.8887 - accuracy: 0.7311 - val_loss: 0.7930 - val_accuracy: 0.7629
# Epoch 12/30
# 130/130 [==============================] - 475s 4s/step - loss: 0.8077 - accuracy: 0.7561 - val_loss: 0.8148 - val_accuracy: 0.7585
# Epoch 13/30
# 130/130 [==============================] - 508s 4s/step - loss: 0.7604 - accuracy: 0.7600 - val_loss: 0.7707 - val_accuracy: 0.7643
# Epoch 14/30
# 130/130 [==============================] - 499s 4s/step - loss: 0.7488 - accuracy: 0.7658 - val_loss: 0.6703 - val_accuracy: 0.7825
# Epoch 15/30
# 130/130 [==============================] - 458s 4s/step - loss: 0.6914 - accuracy: 0.7718 - val_loss: 0.7581 - val_accuracy: 0.7737
# Epoch 16/30
# 130/130 [==============================] - 360s 3s/step - loss: 0.6450 - accuracy: 0.7749 - val_loss: 0.7242 - val_accuracy: 0.7810
# Epoch 17/30
# 130/130 [==============================] - 409s 3s/step - loss: 0.6510 - accuracy: 0.7811 - val_loss: 0.7587 - val_accuracy: 0.7563
# Epoch 18/30
# 130/130 [==============================] - 411s 3s/step - loss: 0.6219 - accuracy: 0.7961 - val_loss: 0.6972 - val_accuracy: 0.7723
# Epoch 19/30
# 130/130 [==============================] - 418s 3s/step - loss: 0.6081 - accuracy: 0.7961 - val_loss: 0.7706 - val_accuracy: 0.7694
# /Users/kristy/opt/anaconda3/envs/metis/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# INFO:tensorflow:Assets written to: ram://5c241b16-9838-49d0-a1e1-a0384d46b66e/assets
# /Users/kristy/opt/anaconda3/envs/metis/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /Users/kristy/opt/anaconda3/envs/metis/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %%
#Xception= keras.models.load_model('model_h5_file/Xception_model_array.h5')
y_pred = np.argmax(Xception.predict(X_test),axis =1)

# %%
print("accuracy :",accuracy_score(y_test, y_pred))
print('recall :',recall_score(y_test,y_pred,average = 'macro'))
print('precision :', precision_score(y_test,y_pred,average = 'macro'))
print('f1 :', f1_score(y_test,y_pred,average = 'macro'))
# Out:
# accuracy : 0.8085569253081943
# recall : 0.8085844894646969
# precision : 0.8432986937995359
# f1 : 0.8232385546856659

# %%
plt.figure(figsize=(10,8))
#plt.subplot(131)
ax = sns.heatmap(confusion_matrix(y_test,y_pred),
            annot = True, annot_kws={"size":20}, fmt="d",cmap = "Blues")

plt.title('Confusion Matrix', size=25)
plt.xlabel('Predicted Outcome', size=20)
plt.ylabel('Actual Outcome', size=20)
labels = [ int_category_map.get(key) for key in sorted(int_category_map.keys())]
ax.set_xticklabels(labels, size=15,rotation = 45)
ax.set_yticklabels(labels, size=15,rotation = 0)
plt.tight_layout()
plt.show();

# %% [markdown]
# ##  Train Xception parameters

# %%
if os.path.exists('model_h5_file/Xception_model_array_trainable.h5') == False:
    Xception_base.trainable = True
    Xception.summary()

    Xception.compile(
        optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
        loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=['accuracy'])
    
    Xception_base_trainable_result = Xception.fit(train_ds,
                                                 validation_data= val_ds, 
                                                  epochs=20, 
                                                  verbose=1,
                                                  batch_size =32,
                                                 callbacks = keras.callbacks.EarlyStopping(patience=2) )  # track progress as we fit
    Xception.save("model_h5_file/Xception_model_array_trainable.h5")
# Out:
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_43 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  tf.math.truediv_6 (TFOpLamb  (None, 150, 150, 3)      0
#  da)
#
#  tf.math.subtract_6 (TFOpLam  (None, 150, 150, 3)      0
#  bda)
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense_51 (Dense)            (None, 32)                1638432
#
#  dropout_30 (Dropout)        (None, 32)                0
#
#  dense_52 (Dense)            (None, 32)                1056
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_53 (Dense)            (None, 32)                1056
#
#  dropout_32 (Dropout)        (None, 32)                0
#
#  dense_54 (Dense)            (None, 8)                 264
#
# =================================================================
# Total params: 22,502,288
# Trainable params: 1,640,808
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/20
# 130/130 [==============================] - 148s 1s/step - loss: 0.5095 - accuracy: 0.8283 - val_loss: 0.7298 - val_accuracy: 0.7781
# Epoch 2/20
# 130/130 [==============================] - 135s 1s/step - loss: 0.4936 - accuracy: 0.8261 - val_loss: 0.7153 - val_accuracy: 0.7629
# Epoch 3/20
# 130/130 [==============================] - 135s 1s/step - loss: 0.4885 - accuracy: 0.8353 - val_loss: 0.6905 - val_accuracy: 0.7687
# Epoch 4/20
# 130/130 [==============================] - 134s 1s/step - loss: 0.5025 - accuracy: 0.8309 - val_loss: 0.7042 - val_accuracy: 0.7781
# Epoch 5/20
# 130/130 [==============================] - 133s 1s/step - loss: 0.4750 - accuracy: 0.8316 - val_loss: 0.7015 - val_accuracy: 0.7672

# %%
y_pred = np.argmax(Xception.predict(X_test),axis =1)
print("accuracy :",accuracy_score(y_test, y_pred))
print('recall :',recall_score(y_test,y_pred,average = 'macro'))
print('precision :', precision_score(y_test,y_pred,average = 'macro'))
print('f1 :', f1_score(y_test,y_pred,average = 'macro'))
# Out:
# accuracy : 0.8179840464104423
# recall : 0.8176205087392772
# precision : 0.845593934208118
# f1 : 0.8302774563570348

# %%
plt.figure(figsize=(10,8))
#plt.subplot(131)
ax = sns.heatmap(confusion_matrix(y_test,y_pred),
            annot = True, annot_kws={"size":20}, fmt="d",cmap = "Blues")

plt.title('Confusion Matrix', size=25)
plt.xlabel('Predicted Outcome', size=20)
plt.ylabel('Actual Outcome', size=20)
labels = [ int_category_map.get(key) for key in sorted(int_category_map.keys())]
ax.set_xticklabels(labels, size=15,rotation = 45)
ax.set_yticklabels(labels, size=15,rotation = 0)
plt.tight_layout()
plt.show();

# %%
X_incorrect = X_test[y_test != y_pred]
y_pred_incorrect = y_pred[y_test != y_pred]
y_test_incorrect = y_test[y_test != y_pred]
len(X_incorrect)
# Out:
# 252

# %%
df = pd.read_csv("work_data_df",index_col = 0 )
df_test = df[df['class'] == "test"] 
pred_cate = [int_category_map.get(i) for i in y_pred]
df_test['pred_cate'] = pred_cate
df_test_incorrect = df_test[df_test.category != df_test.pred_cate]
df_test_incorrect
# Out:
# /var/folders/py/tfswslv1637f5tfr0ngkmsgr0000gn/T/ipykernel_5140/3250642109.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['pred_cate'] = pred_cate
#                                           image_path      category class  \
# 5     work_data/test/Gasoline Can/GasolineCan203.jpg  Gasoline Can  test
# 12    work_data/test/Gasoline Can/GasolineCan216.jpg  Gasoline Can  test
# 19    work_data/test/Gasoline Can/GasolineCan174.jpg  Gasoline Can  test
# 20    work_data/test/Gasoline Can/GasolineCan189.jpg  Gasoline Can  test
# 22    work_data/test/Gasoline Can/GasolineCan176.jpg  Gasoline Can  test
# ...                                              ...           ...   ...
# 1353              work_data/test/pliers/Pliers83.jpg        pliers  test
# 1354             work_data/test/pliers/Pliers299.jpg        pliers  test
# 1360             work_data/test/pliers/Pliers138.jpg        pliers  test
# 1369             work_data/test/pliers/Pliers139.jpg        pliers  test
# 1378              work_data/test/pliers/Pliers80.jpg        pliers  test
#
#          pred_cate
# 5     Screw Driver
# 12    Screw Driver
# 19         Toolbox
# 20         Toolbox
# 22    Screw Driver
# ...            ...
# 1353        Hammer
# 1354        Wrench
# 1360        Wrench
# 1369        Wrench
# 1378        Wrench
#
# [252 rows x 4 columns]

# %% [markdown]
# #  Transfer learning with VGG16

# %%
vgg16_base = keras.applications.vgg16.VGG16(
                                            include_top= False, 
                                            weights='imagenet', 
                                            input_shape= (150,150,3))

# %% [markdown]
# ### Freeze vgg16 parameters and exclude top layers

# %%
if os.path.exists("model_h5_file/vgg16_model_array.h5") == False:
    


    vgg16_base.trainable = False

    inputs = keras.Input(shape=(150, 150, 3))
    
    x = keras.applications.vgg16.preprocess_input(inputs)
    x = vgg16_base(x, training=False)

    x = Flatten()(x)
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)
    outputs = keras.layers.Dense(8)(x)
    vgg16 = keras.Model(inputs, outputs)

    vgg16.summary()
   
    vgg16.compile(
        loss = keras.losses.SparseCategoricalCrossentropy(from_logits= True),
        optimizer = 'Adam',
        metrics=['accuracy'],
    )

    vgg16_result = vgg16.fit(train_ds,
                                validation_data= val_ds,
                                epochs=30, 
                                verbose=1,
                                batch_size =32,
                                callbacks = keras.callbacks.EarlyStopping(patience=5)) 

    vgg16.save("model_h5_file/vgg16_model_array.h5")
    
#     with open('vgg16_result.pickle','wb')as file:
#         pickle.dump(vgg16_result, file)

else: 
    vgg16 = keras.models.load_model('model_h5_file/vgg16_model_array.h5')
        
#     with open('vgg16_result.pickle','rb') as file:
#         vgg16_result = pickle.load(file)

# %%
#test_ds = IMG.ImageDataGenerator(rescale=1./255).flow(X_test, y_test, batch_size=1)

# %%
vgg16 = keras.models.load_model('model_h5_file/vgg16_model_array.h5')

y_pred = np.argmax(vgg16.predict(X_test),axis=1)

#y_pred = np.argmax(vgg16.predict(test_ds),axis=1)

# %%
print("accuracy :",accuracy_score(y_test, y_pred))
print('recall :',recall_score(y_test,y_pred,average = 'macro'))
print('precision :', precision_score(y_test,y_pred,average = 'macro'))
print('f1 :', f1_score(y_test,y_pred,average = 'macro'))
# Out:
# accuracy : 0.6918056562726613
# recall : 0.6881877236709039
# precision : 0.6835300777392442
# f1 : 0.678469383068155

# %% [markdown]
# ### Train VGG16 parameters

# %%
if os.path.exists('model_h5_file/vgg16_model_array_trainable.h5') == False:

    vgg16_base.trainable = True
    vgg16.summary()

    vgg16.compile(
                optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
                loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy']
                )
    
    vgg16_result = vgg16.fit(train_ds, 
                         validation_data = val_ds,
                         epochs = 100,
                         callbacks = keras.callbacks.EarlyStopping(patience=5),
                         verbose =1,
                         batch_size = 32)
    vgg16.save('vgg16_model_array_trainable.h5')
# Out:
# Model: "model_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_53 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  tf.__operators__.getitem_12  (None, 150, 150, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_12 (TFOpLamb  (None, 150, 150, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 8192)              0
#
#  dense_64 (Dense)            (None, 8)                 65544
#
#  dropout_38 (Dropout)        (None, 8)                 0
#
#  dense_65 (Dense)            (None, 8)                 72
#
# =================================================================
# Total params: 14,780,304
# Trainable params: 65,616
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 130/130 [==============================] - 317s 2s/step - loss: 11.4155 - accuracy: 0.3232 - val_loss: 6.8500 - val_accuracy: 0.4445
# Epoch 2/100
# 130/130 [==============================] - 303s 2s/step - loss: 11.1317 - accuracy: 0.3304 - val_loss: 6.3952 - val_accuracy: 0.4873
# Epoch 3/100
# 130/130 [==============================] - 299s 2s/step - loss: 10.8366 - accuracy: 0.3360 - val_loss: 5.9396 - val_accuracy: 0.4808
# Epoch 4/100
# 130/130 [==============================] - 297s 2s/step - loss: 10.4411 - accuracy: 0.3413 - val_loss: 6.3317 - val_accuracy: 0.4909
# Epoch 5/100
# 130/130 [==============================] - 358s 3s/step - loss: 10.6678 - accuracy: 0.3514 - val_loss: 6.0649 - val_accuracy: 0.4982
# Epoch 6/100
# 130/130 [==============================] - 361s 3s/step - loss: 10.2134 - accuracy: 0.3540 - val_loss: 6.1191 - val_accuracy: 0.5047
# Epoch 7/100
# 130/130 [==============================] - 351s 3s/step - loss: 10.1101 - accuracy: 0.3588 - val_loss: 5.9700 - val_accuracy: 0.5134
# Epoch 8/100
# 130/130 [==============================] - 349s 3s/step - loss: 10.0101 - accuracy: 0.3680 - val_loss: 5.9097 - val_accuracy: 0.5062
# Epoch 9/100
# 130/130 [==============================] - 348s 3s/step - loss: 10.1570 - accuracy: 0.3721 - val_loss: 5.9027 - val_accuracy: 0.5395
# Epoch 10/100
# 130/130 [==============================] - 351s 3s/step - loss: 9.4854 - accuracy: 0.3769 - val_loss: 5.7976 - val_accuracy: 0.5149
# Epoch 11/100
# 130/130 [==============================] - 350s 3s/step - loss: 9.1813 - accuracy: 0.3807 - val_loss: 5.2244 - val_accuracy: 0.5569
# Epoch 12/100
# 130/130 [==============================] - 354s 3s/step - loss: 9.2167 - accuracy: 0.3838 - val_loss: 5.3743 - val_accuracy: 0.5482
# Epoch 13/100
# 130/130 [==============================] - 346s 3s/step - loss: 8.9677 - accuracy: 0.3843 - val_loss: 5.2781 - val_accuracy: 0.5315
# Epoch 14/100
# 130/130 [==============================] - 349s 3s/step - loss: 8.8256 - accuracy: 0.3961 - val_loss: 5.1231 - val_accuracy: 0.5460
# Epoch 15/100
# 130/130 [==============================] - 347s 3s/step - loss: 8.5929 - accuracy: 0.3975 - val_loss: 5.1060 - val_accuracy: 0.5591
# Epoch 16/100
# 130/130 [==============================] - 346s 3s/step - loss: 8.5673 - accuracy: 0.3874 - val_loss: 4.8503 - val_accuracy: 0.5816
# Epoch 17/100
# 130/130 [==============================] - 351s 3s/step - loss: 8.3959 - accuracy: 0.4086 - val_loss: 5.0167 - val_accuracy: 0.5772
# Epoch 18/100
# 130/130 [==============================] - 347s 3s/step - loss: 8.5131 - accuracy: 0.3997 - val_loss: 4.9409 - val_accuracy: 0.5859
# Epoch 19/100
# 130/130 [==============================] - 347s 3s/step - loss: 8.2582 - accuracy: 0.4021 - val_loss: 4.6530 - val_accuracy: 0.5743
# Epoch 20/100
# 130/130 [==============================] - 349s 3s/step - loss: 8.0142 - accuracy: 0.4139 - val_loss: 4.8545 - val_accuracy: 0.5700
# Epoch 21/100
# 130/130 [==============================] - 348s 3s/step - loss: 7.9313 - accuracy: 0.4153 - val_loss: 4.8143 - val_accuracy: 0.5823
# Epoch 22/100
# 130/130 [==============================] - 348s 3s/step - loss: 8.2157 - accuracy: 0.4012 - val_loss: 4.5939 - val_accuracy: 0.5874
# Epoch 23/100
# 130/130 [==============================] - 341s 3s/step - loss: 8.1534 - accuracy: 0.4202 - val_loss: 4.6823 - val_accuracy: 0.5743
# Epoch 24/100
# 130/130 [==============================] - 346s 3s/step - loss: 8.2834 - accuracy: 0.4141 - val_loss: 4.4985 - val_accuracy: 0.5722
# Epoch 25/100
# 130/130 [==============================] - 350s 3s/step - loss: 7.6284 - accuracy: 0.4370 - val_loss: 4.5435 - val_accuracy: 0.6120
# Epoch 26/100
# 130/130 [==============================] - 342s 3s/step - loss: 7.6820 - accuracy: 0.4430 - val_loss: 4.5570 - val_accuracy: 0.5946
# Epoch 27/100
# 130/130 [==============================] - 346s 3s/step - loss: 7.6816 - accuracy: 0.4370 - val_loss: 4.5882 - val_accuracy: 0.5751
# Epoch 28/100
# 130/130 [==============================] - 342s 3s/step - loss: 7.7466 - accuracy: 0.4269 - val_loss: 4.6033 - val_accuracy: 0.5852
# Epoch 29/100
# 130/130 [==============================] - 343s 3s/step - loss: 7.7361 - accuracy: 0.4291 - val_loss: 4.6146 - val_accuracy: 0.5801

# %%
vgg16 = keras.models.load_model(model_h5_file/'vgg16_model_array_trainable.h5')
y_pred = np.argmax(vgg16.predict(X_test),axis=1)
print("accuracy :",accuracy_score(y_test, y_pred))
print('recall :',recall_score(y_test,y_pred,average = 'macro'))
print('precision :', precision_score(y_test,y_pred,average = 'macro'))
print('f1 :', f1_score(y_test,y_pred,average = 'macro'))
# Out:
# accuracy : 0.6519216823785352
# recall : 0.6483713709924468
# precision : 0.6388444541477268
# f1 : 0.6388283506239494

# %% [markdown]
# ## Transfer Learning with mobilenet_v2

# %%
mobilnetv2_base = keras.applications.mobilenet_v2.MobileNetV2(weights="imagenet", 
                                            input_shape=(150, 150, 3),
                                            include_top=False) 

mobilnetv2_base.trainable = False


if os.path.exists("mobilnetv2_base_array-.h5") == False:
    

    inputs = keras.Input(shape=(150, 150, 3))

    #x = data_augmentation(inputs)  # Apply random data augmentation
    
    x = keras.applications.mobilenet_v2.preprocess_input(inputs)
    x = mobilnetv2_base(x, training=False)
    
    x = Flatten()(x)
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)
    x = keras.layers.Dense(32)(x)
    x = keras.layers.Dropout(0.2)(x)
    outputs = keras.layers.Dense(8)(x)
    mobilnetv2 = keras.Model(inputs,outputs)

    mobilnetv2.summary()



    mobilnetv2.compile(
        #loss='categorical_crossentropy',
        loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer= keras.optimizers.Adam(learning_rate=0.0005),
        #optimizer = 'Adam',
        metrics=['accuracy'],
    )



    mobilnetv2_result = mobilnetv2.fit(train_ds,
                                validation_data= val_ds,
                                epochs=100, 
                                verbose=1, 
                                callbacks = keras.callbacks.EarlyStopping(patience=5))  # track progress as we fit

    mobilnetv2.save("model_h5_file/mobilnetv2_base_array.h5")
    with open('mobilnetv2_base.pickle','wb')as file:
        pickle.dump(Xception_result, file)

else: 
    mobilnetv2 = keras.models.load_model('model_h5_file/mobilnetv2_base_array.h5')
        
    with open('mobilnetv2_base.pickle','rb') as file:
        mobilnetv2_result = pickle.load(file)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_74 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  tf.math.truediv_13 (TFOpLam  (None, 150, 150, 3)      0
#  bda)
#
#  tf.math.subtract_13 (TFOpLa  (None, 150, 150, 3)      0
#  mbda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 5, 5, 1280)       2257984
#  ional)
#
#  flatten_16 (Flatten)        (None, 32000)             0
#
#  dense_98 (Dense)            (None, 32)                1024032
#
#  dropout_61 (Dropout)        (None, 32)                0
#
#  dense_99 (Dense)            (None, 32)                1056
#
#  dropout_62 (Dropout)        (None, 32)                0
#
#  dense_100 (Dense)           (None, 32)                1056
#
#  dropout_63 (Dropout)        (None, 32)                0
#
#  dense_101 (Dense)           (None, 8)                 264
#
# =================================================================
# Total params: 3,284,392
# Trainable params: 1,026,408
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Epoch 1/100
# 130/130 [==============================] - 60s 439ms/step - loss: 5.6277 - accuracy: 0.5464 - val_loss: 2.2650 - val_accuracy: 0.7353
# Epoch 2/100
# 130/130 [==============================] - 56s 430ms/step - loss: 3.8771 - accuracy: 0.6294 - val_loss: 2.1115 - val_accuracy: 0.7099
# Epoch 3/100
# 130/130 [==============================] - 55s 426ms/step - loss: 3.2591 - accuracy: 0.6383 - val_loss: 1.7637 - val_accuracy: 0.7534
# Epoch 4/100
# 130/130 [==============================] - 55s 423ms/step - loss: 2.8009 - accuracy: 0.6592 - val_loss: 1.5926 - val_accuracy: 0.7542
# Epoch 5/100
# 130/130 [==============================] - 55s 420ms/step - loss: 2.6134 - accuracy: 0.6489 - val_loss: 1.5928 - val_accuracy: 0.7360
# Epoch 6/100
# 130/130 [==============================] - 55s 421ms/step - loss: 2.0660 - accuracy: 0.6799 - val_loss: 1.2179 - val_accuracy: 0.7592
# Epoch 7/100
# 130/130 [==============================] - 55s 423ms/step - loss: 1.8067 - accuracy: 0.6861 - val_loss: 1.2028 - val_accuracy: 0.7418
# Epoch 8/100
# 130/130 [==============================] - 56s 433ms/step - loss: 1.6477 - accuracy: 0.6987 - val_loss: 1.1157 - val_accuracy: 0.7621
# Epoch 9/100
# 130/130 [==============================] - 55s 421ms/step - loss: 1.4166 - accuracy: 0.7051 - val_loss: 1.1234 - val_accuracy: 0.7549
# Epoch 10/100
# 130/130 [==============================] - 53s 408ms/step - loss: 1.3460 - accuracy: 0.7121 - val_loss: 0.9366 - val_accuracy: 0.7621
# Epoch 11/100
# 130/130 [==============================] - 53s 410ms/step - loss: 1.2208 - accuracy: 0.7165 - val_loss: 0.8859 - val_accuracy: 0.7687
# Epoch 12/100
# 130/130 [==============================] - 52s 403ms/step - loss: 1.0740 - accuracy: 0.7273 - val_loss: 0.9207 - val_accuracy: 0.7687
# Epoch 13/100
# 130/130 [==============================] - 55s 422ms/step - loss: 1.0216 - accuracy: 0.7270 - val_loss: 1.0491 - val_accuracy: 0.7513
# Epoch 14/100
# 130/130 [==============================] - 54s 415ms/step - loss: 0.9575 - accuracy: 0.7494 - val_loss: 0.9938 - val_accuracy: 0.7317
# Epoch 15/100
# 130/130 [==============================] - 55s 420ms/step - loss: 0.8986 - accuracy: 0.7489 - val_loss: 0.8182 - val_accuracy: 0.7701
# Epoch 16/100
# 130/130 [==============================] - 54s 415ms/step - loss: 0.8602 - accuracy: 0.7581 - val_loss: 0.8815 - val_accuracy: 0.7491
# Epoch 17/100
# 130/130 [==============================] - 54s 417ms/step - loss: 0.8294 - accuracy: 0.7569 - val_loss: 0.8139 - val_accuracy: 0.7701
# Epoch 18/100
# 130/130 [==============================] - 54s 417ms/step - loss: 0.7511 - accuracy: 0.7732 - val_loss: 0.8023 - val_accuracy: 0.7600
# Epoch 19/100
# 130/130 [==============================] - 54s 413ms/step - loss: 0.7732 - accuracy: 0.7643 - val_loss: 0.8201 - val_accuracy: 0.7513
# Epoch 20/100
# 130/130 [==============================] - 54s 417ms/step - loss: 0.7059 - accuracy: 0.7896 - val_loss: 0.7902 - val_accuracy: 0.7600
# Epoch 21/100
# 130/130 [==============================] - 54s 412ms/step - loss: 0.6454 - accuracy: 0.7852 - val_loss: 0.7938 - val_accuracy: 0.7498
# Epoch 22/100
# 130/130 [==============================] - 57s 437ms/step - loss: 0.6182 - accuracy: 0.7927 - val_loss: 0.7738 - val_accuracy: 0.7650
# Epoch 23/100
# 130/130 [==============================] - 56s 427ms/step - loss: 0.6072 - accuracy: 0.8004 - val_loss: 0.7335 - val_accuracy: 0.7781
# Epoch 24/100
# 130/130 [==============================] - 54s 413ms/step - loss: 0.5904 - accuracy: 0.8098 - val_loss: 0.8412 - val_accuracy: 0.7621
# Epoch 25/100
# 130/130 [==============================] - 54s 414ms/step - loss: 0.6363 - accuracy: 0.7867 - val_loss: 0.7339 - val_accuracy: 0.7796
# Epoch 26/100
# 130/130 [==============================] - 57s 439ms/step - loss: 0.5970 - accuracy: 0.7975 - val_loss: 0.7793 - val_accuracy: 0.7658
# Epoch 27/100
# 130/130 [==============================] - 60s 465ms/step - loss: 0.5744 - accuracy: 0.8083 - val_loss: 0.7299 - val_accuracy: 0.7788
# Epoch 28/100
# 130/130 [==============================] - 66s 504ms/step - loss: 0.5564 - accuracy: 0.8158 - val_loss: 0.8171 - val_accuracy: 0.7643
# Epoch 29/100
# 130/130 [==============================] - 61s 467ms/step - loss: 0.5825 - accuracy: 0.8117 - val_loss: 0.7130 - val_accuracy: 0.7752
# Epoch 30/100
# 130/130 [==============================] - 52s 402ms/step - loss: 0.5432 - accuracy: 0.8167 - val_loss: 0.7488 - val_accuracy: 0.7752
# Epoch 31/100
# 130/130 [==============================] - 50s 387ms/step - loss: 0.5200 - accuracy: 0.8237 - val_loss: 0.7394 - val_accuracy: 0.7817
# Epoch 32/100
# 130/130 [==============================] - 53s 405ms/step - loss: 0.5550 - accuracy: 0.8098 - val_loss: 0.9225 - val_accuracy: 0.7571
# Epoch 33/100
# 130/130 [==============================] - 55s 422ms/step - loss: 0.5249 - accuracy: 0.8201 - val_loss: 0.7303 - val_accuracy: 0.7578
# Epoch 34/100
# 130/130 [==============================] - 56s 431ms/step - loss: 0.4879 - accuracy: 0.8357 - val_loss: 0.7614 - val_accuracy: 0.7745
# INFO:tensorflow:Assets written to: ram://6b4e59f5-55fe-4e74-b070-31062393383c/assets
# /Users/kristy/opt/anaconda3/envs/metis/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /Users/kristy/opt/anaconda3/envs/metis/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %%
y_pred = np.argmax(mobilnetv2.predict(X_test),axis =1)
print("accuracy :",accuracy_score(y_test, y_pred))
print('recall :',recall_score(y_test,y_pred,average = 'macro'))
print('precision :', precision_score(y_test,y_pred,average = 'macro'))
print('f1 :', f1_score(y_test,y_pred,average = 'macro'))
# Out:
# accuracy : 0.8143582306018854
# recall : 0.8354748277086121
# precision : 0.8203054926338201
# f1 : 0.8255911179401066

# %%
acc = mobilnetv2_result.history['accuracy']
val_acc = mobilnetv2_result.history['val_accuracy']
loss = mobilnetv2_result.history['loss']
val_loss = mobilnetv2_result.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r.', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.subplot(131)
ax = sns.heatmap(confusion_matrix(y_test,y_pred),
            annot = True, annot_kws={"size":20}, fmt="d",cmap = "Blues")

plt.title('Confusion Matrix', size=25)
plt.xlabel('Predicted Category', size=20)
plt.ylabel('Actual Category', size=20)
labels = [ int_category_map.get(key) for key in sorted(int_category_map.keys())]
ax.set_xticklabels(labels, size=15,rotation = 45)
ax.set_yticklabels(labels, size=15,rotation = 0)
plt.tight_layout()
plt.show();

# %% [markdown]
# ### Train mobilnetv2 parameters

# %%
if os.path.exists('model_h5_file/mobilnetv2_trainable_array.h5') == False:

    mobilnetv2_base.trainable = True
    mobilnetv2.summary()

    mobilnetv2.compile(
        #loss='categorical_crossentropy',
        loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer= keras.optimizers.Adam(learning_rate=0.001),
        #optimizer = 'Adam',
        metrics=['accuracy'],
    )
    
    mobilnetv2_result = mobilnetv2.fit(train_ds, 
                         validation_data = val_ds,
                         epochs = 100,
                         callbacks = keras.callbacks.EarlyStopping(patience=2),
                         verbose =1,
                         batch_size = 32)
    mobilnetv2.save('model_h5_file/mobilnetv2_trainable_array.h5')
# Out:
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_74 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  tf.math.truediv_13 (TFOpLam  (None, 150, 150, 3)      0
#  bda)
#
#  tf.math.subtract_13 (TFOpLa  (None, 150, 150, 3)      0
#  mbda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 5, 5, 1280)       2257984
#  ional)
#
#  flatten_16 (Flatten)        (None, 32000)             0
#
#  dense_98 (Dense)            (None, 32)                1024032
#
#  dropout_61 (Dropout)        (None, 32)                0
#
#  dense_99 (Dense)            (None, 32)                1056
#
#  dropout_62 (Dropout)        (None, 32)                0
#
#  dense_100 (Dense)           (None, 32)                1056
#
#  dropout_63 (Dropout)        (None, 32)                0
#
#  dense_101 (Dense)           (None, 8)                 264
#
# =================================================================
# Total params: 3,284,392
# Trainable params: 3,250,280
# Non-trainable params: 34,112
# _________________________________________________________________
# Epoch 1/100
# 130/130 [==============================] - 222s 2s/step - loss: 1.8608 - accuracy: 0.2446 - val_loss: 1.8498 - val_accuracy: 0.2516
# Epoch 2/100
# 130/130 [==============================] - 191s 1s/step - loss: 1.8581 - accuracy: 0.2443 - val_loss: 1.8485 - val_accuracy: 0.2516
# Epoch 3/100
# 130/130 [==============================] - 198s 2s/step - loss: 1.8605 - accuracy: 0.2463 - val_loss: 1.8483 - val_accuracy: 0.2516
# Epoch 4/100
# 130/130 [==============================] - 185s 1s/step - loss: 1.8594 - accuracy: 0.2472 - val_loss: 1.8568 - val_accuracy: 0.2516
# Epoch 5/100
# 130/130 [==============================] - 192s 1s/step - loss: 1.8576 - accuracy: 0.2518 - val_loss: 1.8486 - val_accuracy: 0.2516

# %%
y_pred = np.argmax(mobilnetv2.predict(X_test),axis =1)
print("accuracy :",accuracy_score(y_test, y_pred))
print('recall :',recall_score(y_test,y_pred,average = 'macro'))
print('precision :', precision_score(y_test,y_pred,average = 'macro'))
print('f1 :', f1_score(y_test,y_pred,average = 'macro'))
# Out:
# accuracy : 0.2516316171138506
# recall : 0.125
# precision : 0.03145395213923133
# f1 : 0.05026071842410197
# /Users/kristy/opt/anaconda3/envs/metis/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
